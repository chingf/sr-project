# %%
import pickle
import numpy as np
import os
import torch
import torch.nn as nn
import re
import sys
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import matplotlib.pyplot as plt

root = os.path.dirname(os.path.abspath(os.curdir))
sys.path.append(root)

from sr_model.models.models import AnalyticSR, STDP_SR, Linear, MLP
from datasets import inputs, sf_inputs_discrete
from run_td_rnn import run as run_rnn
from run_td_mlp import run as run_mlp
from run_td_linear import run as run_linear
from utils import get_firing_field
import configs

device = 'cpu'

# %% [markdown]
# # Specify dataset and run network

# %%
num_states = 14*14

# %%
# One hot
feature_maker_kwargs = {
    'feature_dim': num_states, 'feature_type': 'nhot'
    }

# Correlated inputs
feature_maker_kwargs = {
    'feature_dim': num_states, 'feature_vals': None,
    'feature_vals_p': [0.99, 0.01],
    'feature_type': 'correlated_distributed',
    'spatial_sigma': 1.25, 'seed_generation': 3
    }

num_steps = 6000

# Regular dataset
reg_dataset_config = {
    'num_steps': num_steps, 'num_states': num_states,
    'feature_maker_kwargs': feature_maker_kwargs,
    'barriers': None
    }
reg_dataset = sf_inputs_discrete.Sim2DWalk

# Barrier dataset
barrier_dataset_config = {
    'num_steps': num_steps, 'num_states': num_states,
    'feature_maker_kwargs': feature_maker_kwargs,
    'barriers': 'transitions'
    }
barrier_dataset = sf_inputs_discrete.Sim2DWalk

input_size = feature_maker_kwargs['feature_dim']

# %%
# Are feature maps the same across walks?
a = barrier_dataset(**barrier_dataset_config)
b = reg_dataset(**reg_dataset_config)
not np.any(a.feature_maker.feature_map != b.feature_maker.feature_map)
# Out:
# True

# %%
input = barrier_dataset(**barrier_dataset_config)
plt.figure();
plt.plot(input.xs, input.ys)
plt.show()

plt.figure();
states = np.argwhere(input.state_inputs)[:,0]
counts = np.zeros(input.num_states)
for state in np.arange(input.num_states):
    counts[state] = np.sum(states==state)
plt.bar(np.arange(input.num_states), counts)
plt.show()
print(np.median(counts))
np.sum(counts == 0)/input.num_states
# Out:
# 29.0
# 0.0

# %%
plt.figure()
plt.imshow(input.feature_maker.feature_map, cmap='viridis')
plt.colorbar()
plt.show()
print(np.sum(input.feature_maker.feature_map)/input.feature_maker.feature_map.size)
# Out:
# 0.07372606997473134

# %%
gamma=0.98

# %%
arena_length = int(np.sqrt(input.num_states)) - 1
walk_xs = input.xs.astype(int)
walk_ys = input.ys.astype(int)

# %% [markdown]
# # Main Option: Use RNN

# %%
rnn = AnalyticSR(
    num_states=input_size, gamma=gamma,
    ca3_kwargs={
        'use_dynamic_lr':False, 'lr':1E-3,
        'rollout':10, 'alpha': 2., 'beta': 2.
        }
    )

reg_outputs, loss, reg_dset = run_rnn(
    '../trained_models/test/', rnn, reg_dataset,
    reg_dataset_config, gamma=gamma, test_over_all=False,
    train_net=False, return_dset=True
    )
rnn.reset()
barrier_outputs, loss, barrier_dset = run_rnn(
    '../trained_models/test/', rnn, barrier_dataset,
    barrier_dataset_config, gamma=gamma, test_over_all=False,
    train_net=False, return_dset=True
    )
# Out:
# [   51] loss: 0.036
# Time per step 0.004s, net 0.192s
#
# [  101] loss: 0.038
# Time per step 0.004s, net 0.402s
#
# [  151] loss: 0.039
# Time per step 0.004s, net 0.619s
#
# [  201] loss: 0.038
# Time per step 0.004s, net 0.833s
#
# [  251] loss: 0.038
# Time per step 0.004s, net 1.054s
#
# [  301] loss: 0.038
# Time per step 0.004s, net 1.275s
#
# [  351] loss: 0.038
# Time per step 0.004s, net 1.486s
#
# [  401] loss: 0.038
# Time per step 0.004s, net 1.703s
#
# [  451] loss: 0.037
# Time per step 0.004s, net 1.922s
#
# [  501] loss: 0.038
# Time per step 0.004s, net 2.133s
#
# [  551] loss: 0.038
# Time per step 0.005s, net 2.360s
#
# [  601] loss: 0.037
# Time per step 0.005s, net 2.598s
#
# [  651] loss: 0.037
# Time per step 0.004s, net 2.802s
#
# [  701] loss: 0.038
# Time per step 0.004s, net 3.015s
#
# [  751] loss: 0.038
# Time per step 0.004s, net 3.215s
#
# [  801] loss: 0.039
# Time per step 0.005s, net 3.490s
#
# [  851] loss: 0.039
# Time per step 0.004s, net 3.701s
#
# [  901] loss: 0.041
# Time per step 0.004s, net 3.906s
#
# [  951] loss: 0.042
# Time per step 0.004s, net 4.112s
#
# [ 1001] loss: 0.042
# Time per step 0.005s, net 4.339s
#
# [ 1051] loss: 0.043
# Time per step 0.005s, net 4.590s
#
# [ 1101] loss: 0.043
# Time per step 0.004s, net 4.806s
#
# [ 1151] loss: 0.043
# Time per step 0.004s, net 5.013s
#
# [ 1201] loss: 0.044
# Time per step 0.005s, net 5.243s
#
# [ 1251] loss: 0.043
# Time per step 0.005s, net 5.474s
#
# [ 1301] loss: 0.042
# Time per step 0.004s, net 5.696s
#
# [ 1351] loss: 0.045
# Time per step 0.005s, net 5.924s
#
# [ 1401] loss: 0.046
# Time per step 0.006s, net 6.199s
#
# [ 1451] loss: 0.047
# Time per step 0.004s, net 6.416s
#
# [ 1501] loss: 0.045
# Time per step 0.004s, net 6.631s
#
# [ 1551] loss: 0.045
# Time per step 0.005s, net 6.861s
#
# [ 1601] loss: 0.046
# Time per step 0.007s, net 7.194s
#
# [ 1651] loss: 0.046
# Time per step 0.008s, net 7.580s
#
# [ 1701] loss: 0.049
# Time per step 0.009s, net 8.052s
#
# [ 1751] loss: 0.050
# Time per step 0.008s, net 8.446s
#
# [ 1801] loss: 0.051
# Time per step 0.007s, net 8.794s
#
# [ 1851] loss: 0.050
# Time per step 0.008s, net 9.217s
#
# [ 1901] loss: 0.050
# Time per step 0.010s, net 9.698s
#
# [ 1951] loss: 0.053
# Time per step 0.010s, net 10.210s
#
# [ 2001] loss: 0.053
# Time per step 0.008s, net 10.611s
#
# [ 2051] loss: 0.055
# Time per step 0.007s, net 10.966s
#
# [ 2101] loss: 0.053
# Time per step 0.006s, net 11.258s
#
# [ 2151] loss: 0.056
# Time per step 0.006s, net 11.562s
#
# [ 2201] loss: 0.055
# Time per step 0.007s, net 11.918s
#
# [ 2251] loss: 0.053
# Time per step 0.007s, net 12.271s
#
# [ 2301] loss: 0.058
# Time per step 0.007s, net 12.629s
#
# [ 2351] loss: 0.056
# Time per step 0.007s, net 12.954s
#
# [ 2401] loss: 0.056
# Time per step 0.007s, net 13.302s
#
# [ 2451] loss: 0.055
# Time per step 0.007s, net 13.650s
#
# [ 2501] loss: 0.058
# Time per step 0.006s, net 13.952s
#
# [ 2551] loss: 0.057
# Time per step 0.007s, net 14.324s
#
# [ 2601] loss: 0.058
# Time per step 0.006s, net 14.640s
#
# [ 2651] loss: 0.060
# Time per step 0.006s, net 14.941s
#
# [ 2701] loss: 0.059
# Time per step 0.006s, net 15.258s
#
# [ 2751] loss: 0.059
# Time per step 0.007s, net 15.628s
#
# [ 2801] loss: 0.058
# Time per step 0.006s, net 15.930s
#
# [ 2851] loss: 0.059
# Time per step 0.008s, net 16.310s
#
# [ 2901] loss: 0.059
# Time per step 0.009s, net 16.759s
#
# [ 2951] loss: 0.061
# Time per step 0.006s, net 17.058s
#
# [ 3001] loss: 0.062
# Time per step 0.006s, net 17.356s
#
# [ 3051] loss: 0.066
# Time per step 0.006s, net 17.659s
#
# [ 3101] loss: 0.062
# Time per step 0.009s, net 18.094s
#
# [ 3151] loss: 0.064
# Time per step 0.006s, net 18.388s
#
# [ 3201] loss: 0.067
# Time per step 0.006s, net 18.685s
#
# [ 3251] loss: 0.062
# Time per step 0.006s, net 18.985s
#
# [ 3301] loss: 0.068
# Time per step 0.009s, net 19.423s
#
# [ 3351] loss: 0.064
# Time per step 0.008s, net 19.838s
#
# [ 3401] loss: 0.067
# Time per step 0.006s, net 20.139s
#
# [ 3451] loss: 0.067
# Time per step 0.006s, net 20.441s
#
# [ 3501] loss: 0.066
# Time per step 0.006s, net 20.745s
#
# [ 3551] loss: 0.072
# Time per step 0.006s, net 21.044s
#
# [ 3601] loss: 0.069
# Time per step 0.007s, net 21.408s
#
# [ 3651] loss: 0.072
# Time per step 0.007s, net 21.746s
#
# [ 3701] loss: 0.073
# Time per step 0.006s, net 22.070s
#
# [ 3751] loss: 0.076
# Time per step 0.006s, net 22.372s
#
# [ 3801] loss: 0.075
# Time per step 0.007s, net 22.733s
#
# [ 3851] loss: 0.075
# Time per step 0.006s, net 23.055s
#
# [ 3901] loss: 0.076
# Time per step 0.007s, net 23.402s
#
# [ 3951] loss: 0.074
# Time per step 0.007s, net 23.757s
#
# [ 4001] loss: 0.075
# Time per step 0.006s, net 24.067s
#
# [ 4051] loss: 0.075
# Time per step 0.007s, net 24.414s
#
# [ 4101] loss: 0.073
# Time per step 0.007s, net 24.743s
#
# [ 4151] loss: 0.072
# Time per step 0.009s, net 25.215s
#
# [ 4201] loss: 0.074
# Time per step 0.008s, net 25.598s
#
# [ 4251] loss: 0.074
# Time per step 0.007s, net 25.950s
#
# [ 4301] loss: 0.074
# Time per step 0.006s, net 26.245s
#
# [ 4351] loss: 0.072
# Time per step 0.006s, net 26.542s
#
# [ 4401] loss: 0.078
# Time per step 0.006s, net 26.857s
#
# [ 4451] loss: 0.077
# Time per step 0.007s, net 27.220s
#
# [ 4501] loss: 0.075
# Time per step 0.006s, net 27.520s
#
# [ 4551] loss: 0.074
# Time per step 0.006s, net 27.822s
#
# [ 4601] loss: 0.077
# Time per step 0.006s, net 28.123s
#
# [ 4651] loss: 0.077
# Time per step 0.007s, net 28.471s
#
# [ 4701] loss: 0.077
# Time per step 0.006s, net 28.788s
#
# [ 4751] loss: 0.076
# Time per step 0.007s, net 29.131s
#
# [ 4801] loss: 0.075
# Time per step 0.006s, net 29.437s
#
# [ 4851] loss: 0.075
# Time per step 0.006s, net 29.760s
#
# [ 4901] loss: 0.078
# Time per step 0.007s, net 30.112s
#
# [ 4951] loss: 0.078
# Time per step 0.006s, net 30.414s
#
# [ 5001] loss: 0.080
# Time per step 0.006s, net 30.717s
#
# [ 5051] loss: 0.077
# Time per step 0.010s, net 31.198s
#
# [ 5101] loss: 0.080
# Time per step 0.010s, net 31.689s
#
# [ 5151] loss: 0.081
# Time per step 0.011s, net 32.237s
#
# [ 5201] loss: 0.079
# Time per step 0.008s, net 32.649s
#
# [ 5251] loss: 0.082
# Time per step 0.009s, net 33.097s
#
# [ 5301] loss: 0.080
# Time per step 0.008s, net 33.489s
#
# [ 5351] loss: 0.081
# Time per step 0.006s, net 33.793s
#
# [ 5401] loss: 0.078
# Time per step 0.010s, net 34.269s
#
# [ 5451] loss: 0.080
# Time per step 0.011s, net 34.814s
#
# [ 5501] loss: 0.080
# Time per step 0.009s, net 35.254s
#
# [ 5551] loss: 0.083
# Time per step 0.006s, net 35.551s
#
# [ 5601] loss: 0.084
# Time per step 0.006s, net 35.845s
#
# [ 5651] loss: 0.084
# Time per step 0.006s, net 36.165s
#
# [ 5701] loss: 0.078
# Time per step 0.007s, net 36.497s
#
# [ 5751] loss: 0.081
# Time per step 0.006s, net 36.808s
#
# [ 5801] loss: 0.085
# Time per step 0.009s, net 37.258s
#
# [ 5851] loss: 0.081
# Time per step 0.008s, net 37.658s
#
# [ 5901] loss: 0.081
# Time per step 0.008s, net 38.062s
#
# [ 5951] loss: 0.080
# Time per step 0.007s, net 38.419s
# Finished Training
#
#
# [   51] loss: 0.025
# Time per step 0.007s, net 0.329s
#
# [  101] loss: 0.028
# Time per step 0.007s, net 0.659s
#
# [  151] loss: 0.027
# Time per step 0.007s, net 0.993s
#
# [  201] loss: 0.028
# Time per step 0.006s, net 1.302s
#
# [  251] loss: 0.031
# Time per step 0.006s, net 1.598s
#
# [  301] loss: 0.033
# Time per step 0.006s, net 1.900s
#
# [  351] loss: 0.034
# Time per step 0.006s, net 2.193s
#
# [  401] loss: 0.035
# Time per step 0.006s, net 2.495s
#
# [  451] loss: 0.037
# Time per step 0.006s, net 2.793s
#
# [  501] loss: 0.037
# Time per step 0.006s, net 3.091s
#
# [  551] loss: 0.038
# Time per step 0.007s, net 3.417s
#
# [  601] loss: 0.037
# Time per step 0.007s, net 3.755s
#
# [  651] loss: 0.038
# Time per step 0.006s, net 4.067s
#
# [  701] loss: 0.037
# Time per step 0.008s, net 4.448s
#
# [  751] loss: 0.037
# Time per step 0.010s, net 4.965s
#
# [  801] loss: 0.038
# Time per step 0.010s, net 5.476s
#
# [  851] loss: 0.038
# Time per step 0.008s, net 5.871s
#
# [  901] loss: 0.038
# Time per step 0.007s, net 6.220s
#
# [  951] loss: 0.038
# Time per step 0.006s, net 6.528s
#
# [ 1001] loss: 0.038
# Time per step 0.009s, net 6.993s
#
# [ 1051] loss: 0.039
# Time per step 0.010s, net 7.493s
#
# [ 1101] loss: 0.039
# Time per step 0.007s, net 7.839s
#
# [ 1151] loss: 0.039
# Time per step 0.010s, net 8.332s
#
# [ 1201] loss: 0.039
# Time per step 0.010s, net 8.821s
#
# [ 1251] loss: 0.039
# Time per step 0.009s, net 9.263s
#
# [ 1301] loss: 0.040
# Time per step 0.006s, net 9.582s
#
# [ 1351] loss: 0.040
# Time per step 0.006s, net 9.891s
#
# [ 1401] loss: 0.039
# Time per step 0.006s, net 10.190s
#
# [ 1451] loss: 0.041
# Time per step 0.006s, net 10.499s
#
# [ 1501] loss: 0.043
# Time per step 0.006s, net 10.798s
#
# [ 1551] loss: 0.041
# Time per step 0.006s, net 11.109s
# [ 1601] loss: 0.043
# Time per step 0.008s, net 11.495s
#
# [ 1651] loss: 0.044
# Time per step 0.006s, net 11.795s
#
# [ 1701] loss: 0.043
# Time per step 0.007s, net 12.124s
#
# [ 1751] loss: 0.044
# Time per step 0.006s, net 12.426s
#
# [ 1801] loss: 0.045
# Time per step 0.006s, net 12.730s
#
# [ 1851] loss: 0.044
# Time per step 0.006s, net 13.030s
#
# [ 1901] loss: 0.044
# Time per step 0.006s, net 13.333s
#
# [ 1951] loss: 0.047
# Time per step 0.008s, net 13.721s
#
# [ 2001] loss: 0.046
# Time per step 0.006s, net 14.035s
#
# [ 2051] loss: 0.048
# Time per step 0.006s, net 14.346s
#
# [ 2101] loss: 0.047
# Time per step 0.007s, net 14.692s
#
# [ 2151] loss: 0.049
# Time per step 0.006s, net 14.994s
#
# [ 2201] loss: 0.051
# Time per step 0.006s, net 15.301s
#
# [ 2251] loss: 0.053
# Time per step 0.008s, net 15.703s
#
# [ 2301] loss: 0.052
# Time per step 0.006s, net 16.008s
#
# [ 2351] loss: 0.053
# Time per step 0.008s, net 16.397s
#
# [ 2401] loss: 0.051
# Time per step 0.008s, net 16.778s
#
# [ 2451] loss: 0.053
# Time per step 0.010s, net 17.257s
#
# [ 2501] loss: 0.052
# Time per step 0.008s, net 17.667s
#
# [ 2551] loss: 0.053
# Time per step 0.006s, net 17.986s
#
# [ 2601] loss: 0.052
# Time per step 0.006s, net 18.307s
#
# [ 2651] loss: 0.053
# Time per step 0.006s, net 18.618s
#
# [ 2701] loss: 0.054
# Time per step 0.006s, net 18.913s
#
# [ 2751] loss: 0.055
# Time per step 0.007s, net 19.284s
#
# [ 2801] loss: 0.054
# Time per step 0.007s, net 19.637s
#
# [ 2851] loss: 0.055
# Time per step 0.006s, net 19.948s
#
# [ 2901] loss: 0.055
# Time per step 0.006s, net 20.245s
#
# [ 2951] loss: 0.056
# Time per step 0.006s, net 20.544s
#
# [ 3001] loss: 0.056
# Time per step 0.006s, net 20.847s
#
# [ 3051] loss: 0.057
# Time per step 0.006s, net 21.146s
#
# [ 3101] loss: 0.058
# Time per step 0.006s, net 21.440s
#
# [ 3151] loss: 0.062
# Time per step 0.006s, net 21.760s
#
# [ 3201] loss: 0.059
# Time per step 0.006s, net 22.064s
#
# [ 3251] loss: 0.059
# Time per step 0.006s, net 22.375s
#
# [ 3301] loss: 0.058
# Time per step 0.006s, net 22.675s
#
# [ 3351] loss: 0.059
# Time per step 0.006s, net 22.984s
#
# [ 3401] loss: 0.061
# Time per step 0.007s, net 23.330s
#
# [ 3451] loss: 0.061
# Time per step 0.007s, net 23.658s
#
# [ 3501] loss: 0.062
# Time per step 0.007s, net 23.995s
#
# [ 3551] loss: 0.061
# Time per step 0.008s, net 24.392s
#
# [ 3601] loss: 0.063
# Time per step 0.007s, net 24.722s
#
# [ 3651] loss: 0.063
# Time per step 0.007s, net 25.050s
#
# [ 3701] loss: 0.061
# Time per step 0.007s, net 25.409s
#
# [ 3751] loss: 0.063
# Time per step 0.009s, net 25.837s
#
# [ 3801] loss: 0.062
# Time per step 0.010s, net 26.342s
#
# [ 3851] loss: 0.064
# Time per step 0.009s, net 26.800s
#
# [ 3901] loss: 0.062
# Time per step 0.011s, net 27.331s
#
# [ 3951] loss: 0.061
# Time per step 0.011s, net 27.869s
#
# [ 4001] loss: 0.063
# Time per step 0.010s, net 28.359s
#
# [ 4051] loss: 0.064
# Time per step 0.010s, net 28.884s
#
# [ 4101] loss: 0.059
# Time per step 0.011s, net 29.421s
#
# [ 4151] loss: 0.062
# Time per step 0.011s, net 29.978s
#
# [ 4201] loss: 0.063
# Time per step 0.008s, net 30.356s
#
# [ 4251] loss: 0.064
# Time per step 0.006s, net 30.671s
#
# [ 4301] loss: 0.064
# Time per step 0.007s, net 31.025s
#
# [ 4351] loss: 0.067
# Time per step 0.008s, net 31.429s
#
# [ 4401] loss: 0.062
# Time per step 0.007s, net 31.760s
#
# [ 4451] loss: 0.066
# Time per step 0.006s, net 32.068s
#
# [ 4501] loss: 0.064
# Time per step 0.007s, net 32.398s
#
# [ 4551] loss: 0.063
# Time per step 0.006s, net 32.696s
#
# [ 4601] loss: 0.066
# Time per step 0.006s, net 32.999s
#
# [ 4651] loss: 0.065
# Time per step 0.006s, net 33.299s
#
# [ 4701] loss: 0.066
# Time per step 0.006s, net 33.593s
#
# [ 4751] loss: 0.065
# Time per step 0.006s, net 33.888s
#
# [ 4801] loss: 0.064
# Time per step 0.006s, net 34.183s
#
# [ 4851] loss: 0.066
# Time per step 0.007s, net 34.515s
#
# [ 4901] loss: 0.065
# Time per step 0.006s, net 34.828s
#
# [ 4951] loss: 0.064
# Time per step 0.006s, net 35.132s
#
# [ 5001] loss: 0.065
# Time per step 0.006s, net 35.429s
#
# [ 5051] loss: 0.064
# Time per step 0.006s, net 35.743s
#
# [ 5101] loss: 0.067
# Time per step 0.006s, net 36.042s
#
# [ 5151] loss: 0.065
# Time per step 0.006s, net 36.343s
#
# [ 5201] loss: 0.065
# Time per step 0.006s, net 36.650s
#
# [ 5251] loss: 0.064
# Time per step 0.006s, net 36.949s
#
# [ 5301] loss: 0.064
# Time per step 0.008s, net 37.345s
#
# [ 5351] loss: 0.065
# Time per step 0.006s, net 37.630s
#
# [ 5401] loss: 0.064
# Time per step 0.006s, net 37.927s
#
# [ 5451] loss: 0.065
# Time per step 0.006s, net 38.228s
#
# [ 5501] loss: 0.065
# Time per step 0.006s, net 38.532s
#
# [ 5551] loss: 0.066
# Time per step 0.006s, net 38.848s
#
# [ 5601] loss: 0.071
# Time per step 0.007s, net 39.200s
#
# [ 5651] loss: 0.069
# Time per step 0.006s, net 39.509s
#
# [ 5701] loss: 0.072
# Time per step 0.007s, net 39.843s
#
# [ 5751] loss: 0.069
# Time per step 0.007s, net 40.177s
#
# [ 5801] loss: 0.069
# Time per step 0.006s, net 40.477s
#
# [ 5851] loss: 0.067
# Time per step 0.006s, net 40.792s
#
# [ 5901] loss: 0.067
# Time per step 0.007s, net 41.147s
#
# [ 5951] loss: 0.068
# Time per step 0.008s, net 41.569s
# Finished Training

# %% [markdown]
# # Debug Option: Run MLP

# %%
rnn = MLP(input_size, input_size*2)

reg_outputs, loss, reg_dset = run_mlp(
    '../trained_models/test/', rnn, reg_dataset,
    reg_dataset_config, gamma=gamma, test_over_all=False,
    return_dset=True
    )
rnn.reset()
barrier_outputs, loss, barrier_dset = run_mlp(
    '../trained_models/test/', rnn, barrier_dataset,
    barrier_dataset_config, gamma=gamma, test_over_all=False,
    return_dset=True
    )
# Out:
# [   51] loss: 0.043
# Time per step 0.006s, net 0.318s
#
# [  101] loss: 0.026
# Time per step 0.009s, net 0.745s
#
# [  151] loss: 0.026
# Time per step 0.010s, net 1.242s
#
# [  201] loss: 0.027
# Time per step 0.010s, net 1.752s
#
# [  251] loss: 0.028
# Time per step 0.011s, net 2.294s
#
# [  301] loss: 0.027
# Time per step 0.014s, net 3.006s
#
# [  351] loss: 0.027
# Time per step 0.011s, net 3.579s
#
# [  401] loss: 0.026
# Time per step 0.012s, net 4.168s
#
# [  451] loss: 0.026
# Time per step 0.013s, net 4.838s
#
# [  501] loss: 0.026
# Time per step 0.013s, net 5.481s
#
# [  551] loss: 0.027
# Time per step 0.015s, net 6.214s
#
# [  601] loss: 0.027
# Time per step 0.015s, net 6.976s
#
# [  651] loss: 0.027
# Time per step 0.016s, net 7.792s
#
# [  701] loss: 0.028
# Time per step 0.017s, net 8.652s
#
# [  751] loss: 0.028
# Time per step 0.018s, net 9.544s
#
# [  801] loss: 0.028
# Time per step 0.018s, net 10.461s
#
# [  851] loss: 0.029
# Time per step 0.019s, net 11.428s
#
# [  901] loss: 0.029
# Time per step 0.020s, net 12.435s
#
# [  951] loss: 0.029
# Time per step 0.020s, net 13.447s
#
# [ 1001] loss: 0.029
# Time per step 0.021s, net 14.518s
#
# [ 1051] loss: 0.029
# Time per step 0.022s, net 15.614s
#
# [ 1101] loss: 0.030
# Time per step 0.022s, net 16.730s
#
# [ 1151] loss: 0.030
# Time per step 0.023s, net 17.896s
#
# [ 1201] loss: 0.030
# Time per step 0.024s, net 19.099s
#
# [ 1251] loss: 0.031
# Time per step 0.025s, net 20.358s
#
# [ 1301] loss: 0.030
# Time per step 0.026s, net 21.638s
#
# [ 1351] loss: 0.031
# Time per step 0.026s, net 22.962s
#
# [ 1401] loss: 0.031
# Time per step 0.037s, net 24.809s
#
# [ 1451] loss: 0.031
# Time per step 0.034s, net 26.494s
#
# [ 1501] loss: 0.031
# Time per step 0.031s, net 28.042s
#
# [ 1551] loss: 0.032
# Time per step 0.029s, net 29.486s
#
# [ 1601] loss: 0.031
# Time per step 0.030s, net 30.981s
#
# [ 1651] loss: 0.031
# Time per step 0.037s, net 32.843s
#
# [ 1701] loss: 0.031
# Time per step 0.035s, net 34.599s
#
# [ 1751] loss: 0.031
# Time per step 0.041s, net 36.674s
#
# [ 1801] loss: 0.031
# Time per step 0.040s, net 38.685s
#
# [ 1851] loss: 0.031
# Time per step 0.038s, net 40.568s
#
# [ 1901] loss: 0.031
# Time per step 0.034s, net 42.260s
#
# [ 1951] loss: 0.032
# Time per step 0.041s, net 44.327s
#
# [ 2001] loss: 0.032
# Time per step 0.045s, net 46.565s
#
# [ 2051] loss: 0.032
# Time per step 0.048s, net 48.952s
#
# [ 2101] loss: 0.032
# Time per step 0.050s, net 51.475s
#
# [ 2151] loss: 0.032
# Time per step 0.045s, net 53.740s
#
# [ 2201] loss: 0.032
# Time per step 0.049s, net 56.181s
#
# [ 2251] loss: 0.032
# Time per step 0.048s, net 58.589s
#
# [ 2301] loss: 0.032
# Time per step 0.045s, net 60.827s
#
# [ 2351] loss: 0.032
# Time per step 0.046s, net 63.150s
#
# [ 2401] loss: 0.032
# Time per step 0.043s, net 65.293s
#
# [ 2451] loss: 0.032
# Time per step 0.042s, net 67.398s
#
# [ 2501] loss: 0.032
# Time per step 0.052s, net 70.005s
#
# [ 2551] loss: 0.032
# Time per step 0.046s, net 72.295s
#
# [ 2601] loss: 0.032
# Time per step 0.063s, net 75.458s
#
# [ 2651] loss: 0.032
# Time per step 0.073s, net 79.125s
#
# [ 2701] loss: 0.032
# Time per step 0.089s, net 83.597s
#
# [ 2751] loss: 0.032
# Time per step 0.078s, net 87.515s
#
# [ 2801] loss: 0.032
# Time per step 0.099s, net 92.444s
#
# [ 2851] loss: 0.032
# Time per step 0.055s, net 95.176s
#
# [ 2901] loss: 0.032
# Time per step 0.052s, net 97.778s
#
# [ 2951] loss: 0.031
# Time per step 0.055s, net 100.534s
#
# [ 3001] loss: 0.032
# Time per step 0.054s, net 103.224s
#
# [ 3051] loss: 0.031
# Time per step 0.045s, net 105.484s
#
# [ 3101] loss: 0.031
# Time per step 0.045s, net 107.754s
#
# [ 3151] loss: 0.032
# Time per step 0.046s, net 110.032s
#
# [ 3201] loss: 0.032
# Time per step 0.047s, net 112.360s
#
# [ 3251] loss: 0.032
# Time per step 0.051s, net 114.930s
#
# [ 3301] loss: 0.032
# Time per step 0.057s, net 117.759s
#
# [ 3351] loss: 0.032
# Time per step 0.075s, net 121.521s
#
# [ 3401] loss: 0.032
# Time per step 0.061s, net 124.547s
#
# [ 3451] loss: 0.032
# Time per step 0.059s, net 127.520s
#
# [ 3501] loss: 0.032
# Time per step 0.058s, net 130.414s
#
# [ 3551] loss: 0.032
# Time per step 0.066s, net 133.690s
#
# [ 3601] loss: 0.032
# Time per step 0.060s, net 136.696s
#
# [ 3651] loss: 0.032
# Time per step 0.063s, net 139.837s
#
# [ 3701] loss: 0.032
# Time per step 0.065s, net 143.110s
#
# [ 3751] loss: 0.032
# Time per step 0.072s, net 146.720s
#
# [ 3801] loss: 0.032
# Time per step 0.066s, net 150.011s
#
# [ 3851] loss: 0.032
# Time per step 0.068s, net 153.421s
#
# [ 3901] loss: 0.032
# Time per step 0.067s, net 156.751s
#
# [ 3951] loss: 0.032
# Time per step 0.072s, net 160.349s
#
# [ 4001] loss: 0.032
# Time per step 0.070s, net 163.872s
#
# [ 4051] loss: 0.032
# Time per step 0.071s, net 167.420s
#
# [ 4101] loss: 0.032
# Time per step 0.072s, net 171.044s
#
# [ 4151] loss: 0.032
# Time per step 0.071s, net 174.584s
#
# [ 4201] loss: 0.032
# Time per step 0.070s, net 178.099s
#
# [ 4251] loss: 0.032
# Time per step 0.070s, net 181.605s
#
# [ 4301] loss: 0.032
# Time per step 0.086s, net 185.918s
#
# [ 4351] loss: 0.032
# Time per step 0.071s, net 189.490s
#
# [ 4401] loss: 0.032
# Time per step 0.073s, net 193.149s
#
# [ 4451] loss: 0.032
# Time per step 0.077s, net 196.997s
#
# [ 4501] loss: 0.032
# Time per step 0.074s, net 200.707s
#
# [ 4551] loss: 0.032
# Time per step 0.075s, net 204.454s
#
# [ 4601] loss: 0.032
# Time per step 0.076s, net 208.264s
#
# [ 4651] loss: 0.032
# Time per step 0.078s, net 212.149s
#
# [ 4701] loss: 0.032
# Time per step 0.080s, net 216.173s
#
# [ 4751] loss: 0.032
# Time per step 0.077s, net 220.029s
#
# [ 4801] loss: 0.032
# Time per step 0.079s, net 223.998s
#
# [ 4851] loss: 0.032
# Time per step 0.082s, net 228.088s
#
# [ 4901] loss: 0.032
# Time per step 0.081s, net 232.124s
#
# [ 4951] loss: 0.032
# Time per step 0.081s, net 236.160s
#
# [ 5001] loss: 0.032
# Time per step 0.082s, net 240.237s
#
# [ 5051] loss: 0.032
# Time per step 0.082s, net 244.340s
#
# [ 5101] loss: 0.032
# Time per step 0.099s, net 249.300s
#
# [ 5151] loss: 0.032
# Time per step 0.080s, net 253.304s
#
# [ 5201] loss: 0.032
# Time per step 0.082s, net 257.382s
#
# [ 5251] loss: 0.032
# Time per step 0.082s, net 261.491s
#
# [ 5301] loss: 0.032
# Time per step 0.082s, net 265.594s
#
# [ 5351] loss: 0.032
# Time per step 0.082s, net 269.693s
#
# [ 5401] loss: 0.032
# Time per step 0.082s, net 273.776s
#
# [ 5451] loss: 0.032
# Time per step 0.083s, net 277.903s
#
# [ 5501] loss: 0.032
# Time per step 0.085s, net 282.169s
#
# [ 5551] loss: 0.032
# Time per step 0.082s, net 286.269s
#
# [ 5601] loss: 0.032
# Time per step 0.085s, net 290.505s
#
# [ 5651] loss: 0.032
# Time per step 0.083s, net 294.639s
#
# [ 5701] loss: 0.032
# Time per step 0.083s, net 298.790s
#
# [ 5751] loss: 0.032
# Time per step 0.083s, net 302.952s
#
# [ 5801] loss: 0.032
# Time per step 0.076s, net 306.730s
#
# [ 5851] loss: 0.032
# Time per step 0.074s, net 310.447s
#
# [ 5901] loss: 0.032
# Time per step 0.078s, net 314.340s
#
# [ 5951] loss: 0.032
# Time per step 0.075s, net 318.087s
# Finished Training
#
#
# [   51] loss: 0.019
# Time per step 0.007s, net 0.356s
#
# [  101] loss: 0.017
# Time per step 0.009s, net 0.781s
#
# [  151] loss: 0.017
# Time per step 0.009s, net 1.254s
#
# [  201] loss: 0.017
# Time per step 0.010s, net 1.754s
#
# [  251] loss: 0.019
# Time per step 0.010s, net 2.272s
#
# [  301] loss: 0.022
# Time per step 0.012s, net 2.855s
#
# [  351] loss: 0.024
# Time per step 0.012s, net 3.451s
#
# [  401] loss: 0.025
# Time per step 0.012s, net 4.068s
#
# [  451] loss: 0.024
# Time per step 0.014s, net 4.746s
#
# [  501] loss: 0.025
# Time per step 0.015s, net 5.473s
#
# [  551] loss: 0.026
# Time per step 0.015s, net 6.215s
#
# [  601] loss: 0.027
# Time per step 0.016s, net 7.019s
#
# [  651] loss: 0.027
# Time per step 0.017s, net 7.864s
#
# [  701] loss: 0.026
# Time per step 0.017s, net 8.720s
#
# [  751] loss: 0.027
# Time per step 0.018s, net 9.618s
#
# [  801] loss: 0.028
# Time per step 0.019s, net 10.557s
#
# [  851] loss: 0.029
# Time per step 0.020s, net 11.540s
#
# [  901] loss: 0.029
# Time per step 0.020s, net 12.551s
#
# [  951] loss: 0.030
# Time per step 0.022s, net 13.632s
#
# [ 1001] loss: 0.030
# Time per step 0.022s, net 14.732s
#
# [ 1051] loss: 0.030
# Time per step 0.023s, net 15.860s
#
# [ 1101] loss: 0.030
# Time per step 0.023s, net 17.030s
#
# [ 1151] loss: 0.030
# Time per step 0.024s, net 18.250s
#
# [ 1201] loss: 0.030
# Time per step 0.025s, net 19.499s
#
# [ 1251] loss: 0.030
# Time per step 0.026s, net 20.797s
#
# [ 1301] loss: 0.030
# Time per step 0.027s, net 22.151s
#
# [ 1351] loss: 0.030
# Time per step 0.042s, net 24.271s
#
# [ 1401] loss: 0.029
# Time per step 0.027s, net 25.640s
#
# [ 1451] loss: 0.030
# Time per step 0.029s, net 27.080s
#
# [ 1501] loss: 0.031
# Time per step 0.029s, net 28.547s
# [ 1551] loss: 0.031
# Time per step 0.031s, net 30.076s
#
# [ 1601] loss: 0.031
# Time per step 0.031s, net 31.647s
#
# [ 1651] loss: 0.031
# Time per step 0.033s, net 33.308s
#
# [ 1701] loss: 0.031
# Time per step 0.033s, net 34.962s
#
# [ 1751] loss: 0.031
# Time per step 0.034s, net 36.657s
#
# [ 1801] loss: 0.031
# Time per step 0.035s, net 38.403s
#
# [ 1851] loss: 0.031
# Time per step 0.036s, net 40.186s
#
# [ 1901] loss: 0.031
# Time per step 0.036s, net 42.001s
#
# [ 1951] loss: 0.031
# Time per step 0.045s, net 44.255s
#
# [ 2001] loss: 0.031
# Time per step 0.038s, net 46.160s
#
# [ 2051] loss: 0.031
# Time per step 0.050s, net 48.661s
#
# [ 2101] loss: 0.031
# Time per step 0.051s, net 51.212s
#
# [ 2151] loss: 0.031
# Time per step 0.060s, net 54.203s
#
# [ 2201] loss: 0.031
# Time per step 0.078s, net 58.102s
#
# [ 2251] loss: 0.031
# Time per step 0.042s, net 60.225s
#
# [ 2301] loss: 0.031
# Time per step 0.041s, net 62.279s
#
# [ 2351] loss: 0.031
# Time per step 0.043s, net 64.412s
#
# [ 2401] loss: 0.031
# Time per step 0.043s, net 66.567s
#
# [ 2451] loss: 0.031
# Time per step 0.047s, net 68.936s
#
# [ 2501] loss: 0.031
# Time per step 0.052s, net 71.522s
#
# [ 2551] loss: 0.031
# Time per step 0.066s, net 74.834s
#
# [ 2601] loss: 0.031
# Time per step 0.046s, net 77.134s
#
# [ 2651] loss: 0.030
# Time per step 0.047s, net 79.485s
#
# [ 2701] loss: 0.030
# Time per step 0.052s, net 82.064s
#
# [ 2751] loss: 0.030
# Time per step 0.049s, net 84.528s
#
# [ 2801] loss: 0.030
# Time per step 0.062s, net 87.626s
#
# [ 2851] loss: 0.030
# Time per step 0.058s, net 90.540s
#
# [ 2901] loss: 0.030
# Time per step 0.051s, net 93.098s
#
# [ 2951] loss: 0.030
# Time per step 0.067s, net 96.473s
#
# [ 3001] loss: 0.031
# Time per step 0.074s, net 100.177s
#
# [ 3051] loss: 0.031
# Time per step 0.079s, net 104.135s
#
# [ 3101] loss: 0.031
# Time per step 0.067s, net 107.467s
#
# [ 3151] loss: 0.031
# Time per step 0.061s, net 110.516s
#
# [ 3201] loss: 0.031
# Time per step 0.056s, net 113.316s
#
# [ 3251] loss: 0.031
# Time per step 0.060s, net 116.294s
#
# [ 3301] loss: 0.031
# Time per step 0.066s, net 119.576s
#
# [ 3351] loss: 0.031
# Time per step 0.060s, net 122.575s
#
# [ 3401] loss: 0.031
# Time per step 0.067s, net 125.927s
#
# [ 3451] loss: 0.031
# Time per step 0.076s, net 129.744s
#
# [ 3501] loss: 0.031
# Time per step 0.060s, net 132.720s
#
# [ 3551] loss: 0.031
# Time per step 0.061s, net 135.756s
#
# [ 3601] loss: 0.031
# Time per step 0.059s, net 138.726s
#
# [ 3651] loss: 0.031
# Time per step 0.061s, net 141.757s
#
# [ 3701] loss: 0.031
# Time per step 0.061s, net 144.831s
#
# [ 3751] loss: 0.031
# Time per step 0.064s, net 148.025s
#
# [ 3801] loss: 0.031
# Time per step 0.076s, net 151.816s
#
# [ 3851] loss: 0.031
# Time per step 0.065s, net 155.062s
#
# [ 3901] loss: 0.031
# Time per step 0.066s, net 158.364s
#
# [ 3951] loss: 0.031
# Time per step 0.067s, net 161.731s
#
# [ 4001] loss: 0.031
# Time per step 0.069s, net 165.195s
#
# [ 4051] loss: 0.031
# Time per step 0.069s, net 168.641s
#
# [ 4101] loss: 0.031
# Time per step 0.069s, net 172.102s
#
# [ 4151] loss: 0.031
# Time per step 0.070s, net 175.596s
#
# [ 4201] loss: 0.031
# Time per step 0.072s, net 179.174s
#
# [ 4251] loss: 0.031
# Time per step 0.076s, net 182.966s
#
# [ 4301] loss: 0.031
# Time per step 0.073s, net 186.600s
#
# [ 4351] loss: 0.031
# Time per step 0.074s, net 190.296s
#
# [ 4401] loss: 0.031
# Time per step 0.075s, net 194.044s
#
# [ 4451] loss: 0.031
# Time per step 0.076s, net 197.820s
#
# [ 4501] loss: 0.031
# Time per step 0.077s, net 201.660s
#
# [ 4551] loss: 0.031
# Time per step 0.080s, net 205.676s
#
# [ 4601] loss: 0.031
# Time per step 0.077s, net 209.548s
#
# [ 4651] loss: 0.031
# Time per step 0.078s, net 213.443s
#
# [ 4701] loss: 0.031
# Time per step 0.082s, net 217.528s
#
# [ 4751] loss: 0.031
# Time per step 0.080s, net 221.536s
#
# [ 4801] loss: 0.031
# Time per step 0.080s, net 225.537s
#
# [ 4851] loss: 0.031
# Time per step 0.081s, net 229.576s
#
# [ 4901] loss: 0.031
# Time per step 0.082s, net 233.683s
#
# [ 4951] loss: 0.031
# Time per step 0.086s, net 238.005s
#
# [ 5001] loss: 0.031
# Time per step 0.083s, net 242.159s
#
# [ 5051] loss: 0.031
# Time per step 0.087s, net 246.510s
#
# [ 5101] loss: 0.031
# Time per step 0.083s, net 250.665s
#
# [ 5151] loss: 0.031
# Time per step 0.083s, net 254.822s
#
# [ 5201] loss: 0.031
# Time per step 0.086s, net 259.125s
#
# [ 5251] loss: 0.031
# Time per step 0.086s, net 263.416s
#
# [ 5301] loss: 0.031
# Time per step 0.087s, net 267.753s
#
# [ 5351] loss: 0.031
# Time per step 0.085s, net 272.025s
#
# [ 5401] loss: 0.031
# Time per step 0.086s, net 276.318s
#
# [ 5451] loss: 0.032
# Time per step 0.089s, net 280.752s
#
# [ 5501] loss: 0.032
# Time per step 0.086s, net 285.033s
#
# [ 5551] loss: 0.031
# Time per step 0.086s, net 289.310s
#
# [ 5601] loss: 0.032
# Time per step 0.086s, net 293.590s
#
# [ 5651] loss: 0.032
# Time per step 0.086s, net 297.870s
#
# [ 5701] loss: 0.032
# Time per step 0.086s, net 302.154s
#
# [ 5751] loss: 0.032
# Time per step 0.086s, net 306.431s
#
# [ 5801] loss: 0.032
# Time per step 0.088s, net 310.842s
#
# [ 5851] loss: 0.032
# Time per step 0.085s, net 315.102s
#
# [ 5901] loss: 0.031
# Time per step 0.086s, net 319.384s
#
# [ 5951] loss: 0.031
# Time per step 0.086s, net 323.671s
# Finished Training

# %% [markdown]
# # Check Similarity Across Walks

# %%
from scipy.stats import pearsonr
import seaborn as sns
import pandas as pd

# %%
barrier_xs = barrier_dset.xs
barrier_ys = barrier_dset.ys
reg_xs = reg_dset.xs
reg_ys = reg_dset.ys
arena_length = int(np.sqrt(barrier_dset.num_states))

# %%
barrier_locs = []
wall = arena_length//2
for x in [wall-2, wall-1, wall, wall+1]:
    for y in np.arange(min(7, wall+1)):
        barrier_locs.append(x*arena_length + y)

# %%
corrs = []
condn = []
barrier_neurs = []

for neur in np.arange(barrier_outputs.shape[1]):
    barrier_field = np.zeros((arena_length, arena_length))
    reg_field = np.zeros((arena_length, arena_length))
    for field_x in range(arena_length):
        for field_y in range(arena_length):
            barrier_frame_idxs = np.logical_and(
                barrier_xs == field_x, barrier_ys == field_y
                )
            barrier_field[field_x, field_y] = np.nanmean(
                barrier_outputs[barrier_frame_idxs, neur]
                )
            barrier_field[np.isnan(barrier_field)] = 0

            reg_frame_idxs = np.logical_and(
                reg_xs == field_x, reg_ys == field_y
                )
            reg_field[field_x, field_y] = np.nanmean(
                reg_outputs[reg_frame_idxs, neur]
                )
            reg_field[np.isnan(reg_field)] = 0
    if barrier_field.max() > 0:
        barrier_field /= barrier_field.max()
    if reg_field.max() > 0:
        reg_field /= reg_field.max()

    r, _ = pearsonr(barrier_field.flatten(), reg_field.flatten())
    fisher_r = np.arctanh(r)
    
    if np.isnan(fisher_r):
        continue

    corrs.append(fisher_r)
    
    is_near = False
    #if np.argmax(reg_field.flatten()) in barrier_locs:
    if np.any(reg_field.flatten()[barrier_locs] > reg_field.max()*0.8):
        is_near = True
        barrier_neurs.append(neur)
#     for barrier_loc in barrier_locs:
#         barrier_feature = reg_dset.feature_maker.feature_map[:,barrier_loc]
#         if barrier_feature[neur] > 0.5:
#             is_near = True
    if is_near:
        condn.append('Near')
    else:
        condn.append('Far')
corrs = np.array(corrs)
condn = np.array(condn)
# Out:
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/scipy/stats/stats.py:3508: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
fig, ax = plt.subplots(figsize=(6.4*0.5, 4.8))
df = pd.DataFrame({'Spatial Similarity': corrs, 'Condition': condn})
sns.barplot(
    x='Condition', y='Spatial Similarity', data=df, ax=ax,
    palette=['lightgrey', 'dimgray']
    )

bar_top = 1.0
fig_dy = 0.4
sigbar_dy1 = 0.15
sigbar_dy2 = 0.25
plt.ylim(0, bar_top + fig_dy)
plt.plot(
   [0, 0, 1, 1],
   [bar_top+sigbar_dy1, bar_top+sigbar_dy2,
   bar_top+sigbar_dy2, bar_top+sigbar_dy1],
   lw=1.5, c='k')
plt.text((0+1)/2, bar_top+sigbar_dy2, "*", ha='center', va='bottom', color='k')

plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Spatial Similarity', fontsize=16)
plt.title('Place Field Change\nAround Barriers')
plt.tight_layout()
plt.savefig('5d_barrier_ranksums.png', dpi=300)
plt.show()

# %%
from scipy.stats import ranksums
ranksums(corrs[condn=='Far'], corrs[condn=='Near'])
# Out:
# RanksumsResult(statistic=2.539347847743099, pvalue=0.011105934082651146)

# %% [markdown]
# # Make Plots

# %%
walk_xs = barrier_dset.xs
walk_ys = barrier_dset.ys
arena_length = int(np.sqrt(barrier_dset.num_states))

# %%
import matplotlib.gridspec as gridspec

grid_x = 4; grid_y = 4;

plt.figure(figsize = (6, 6))
gs1 = gridspec.GridSpec(grid_x, grid_y)
gs1.update(wspace=0.05, hspace=0.05) # set the spacing between axes. 

neurs = np.array(barrier_neurs)
np.random.shuffle(neurs)

idx = 0
for neur in neurs:
    firing_field, _ = get_firing_field(
        barrier_xs, barrier_ys, barrier_outputs[:, neur],
        arena_length
        )
    
#     firing_field = np.zeros((arena_length, arena_length))*np.nan
#     for x in range(arena_length):
#         for y in range(arena_length):
#             frame_idxs = np.logical_and(barrier_xs == x, barrier_ys == y)
#             fr = np.nanmean(barrier_outputs[frame_idxs, neur])
#             firing_field[x,y] = fr
#     firing_field[np.isnan(firing_field)] = 0    
#     if not np.any(firing_field > 0): continue
        
    ax = plt.subplot(gs1[idx])
    plt.axis('on')
    ax.imshow(firing_field/firing_field.max(), vmin=0, vmax=1, cmap='viridis')
    ax.plot([-0.5, arena_length/2], [arena_length//2 -1, arena_length//2 -1], 'red', linewidth=3)
    ax.set_xticks([])
    ax.set_yticks([])
    
    idx += 1
    if idx == grid_x*grid_y: break
plt.suptitle('Barrier')
plt.savefig('5d_barriers.png', dpi=300)
plt.show()

# %%
import matplotlib.gridspec as gridspec

grid_x = 4; grid_y = 4;

plt.figure(figsize = (6, 6))
gs1 = gridspec.GridSpec(grid_x, grid_y)
gs1.update(wspace=0.05, hspace=0.05) # set the spacing between axes. 

idx = 0
for neur in neurs:
    firing_field, _ = get_firing_field(
        reg_xs, reg_ys, reg_outputs[:, neur],
        arena_length
        )
    
#     firing_field = np.zeros((arena_length, arena_length))*np.nan
#     for x in range(arena_length):
#         for y in range(arena_length):
#             frame_idxs = np.logical_and(reg_xs == x, reg_ys == y)
#             fr = np.nanmean(reg_outputs[frame_idxs, neur])
#             firing_field[x,y] = fr
#     firing_field[np.isnan(firing_field)] = 0
    
    if not np.any(firing_field > 0): continue
    ax = plt.subplot(gs1[idx])
    plt.axis('on')
    ax.imshow(firing_field/firing_field.max(), vmin=0, vmax=1, cmap='viridis')
    ax.set_xticks([])
    ax.set_yticks([])
    
    idx += 1
    if idx == grid_x*grid_y: break
plt.suptitle('No Barrier')
plt.savefig('5d_no_barriers.png', dpi=300)
plt.show()
