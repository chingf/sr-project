# %%
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
names = []
dicts = []
for f in sorted(os.listdir("pickles")):
    filepath = "pickles/" + f + ""
    with open(filepath, "rb") as _f:
        names.append(f)
        dicts.append(pickle.load(_f))

# %%
plt.figure()
for name, dic in zip(names, dicts):
    plt.plot(dic['T_probabilities'], label=name)
plt.title("Mean Total Probability")
#plt.ylim(0,1.1)
#plt.xlim(-10,250)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.show()

# %%
plt.figure()
for name, dic in zip(names, dicts):
    plt.plot(dic['T_error'], label=name)
plt.title("Mean Error in T")
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
#plt.xlim(-10,250)
plt.show()

# %%
for name, dic in zip(names, dicts):
    plt.figure()
    for i, _gamma in enumerate(dic['test_gammas']):
        plt.plot(dic['M_error'][i], label=str(_gamma))
    plt.title(f'Mean Error in M: {name[:-2]}')
    plt.legend(title="Gamma Value")
    plt.show()
