# %%
import pickle
import numpy as np
import os
import torch
import torch.nn as nn
import re
import sys
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import matplotlib.pyplot as plt

root = os.path.dirname(os.path.abspath(os.curdir))
sys.path.append(root)

from sr_model.models.models import AnalyticSR, STDP_SR, Linear, MLP
from datasets import inputs, sf_inputs_discrete
from run_td_rnn import run as run_rnn
from run_td_mlp import run as run_mlp
from run_td_linear import run as run_linear

device = 'cpu'
# Out:
# /home/chingf/Code/sr-project/datasets/inputs.py:12: UserWarning: Emily's experimental data could not be loaded.
#   warnings.warn("Emily's experimental data could not be loaded.")
# /home/chingf/Code/sr-project/datasets/sf_inputs_discrete.py:19: UserWarning: Emily's experimental data could not be loaded.
#   warnings.warn("Emily's experimental data could not be loaded.")

# %% [markdown]
# # Specify dataset and run network

# %%
num_states = 20*20

# %%
# One hot
feature_maker_kwargs = {
    'feature_dim': num_states, 'feature_type': 'nhot'
    }

# Correlated inputs
feature_maker_kwargs = {
    'feature_dim': num_states, 'feature_vals': None,
    'feature_vals_p': [0.98, 0.02],
    'feature_type': 'correlated_distributed',
    'spatial_sigma': 1.75, 'seed_generation': 3
    }

# Regular dataset
reg_dataset_config = {
    'num_steps': 6000, 'num_states': num_states,
    'feature_maker_kwargs': feature_maker_kwargs,
    'barriers': None
    }
reg_dataset = sf_inputs_discrete.Sim2DWalk

# Barrier dataset
barrier_dataset_config = {
    'num_steps': 6000, 'num_states': num_states,
    'feature_maker_kwargs': feature_maker_kwargs,
    'barriers': 'transitions'
    }
barrier_dataset = sf_inputs_discrete.Sim2DWalk

input_size = feature_maker_kwargs['feature_dim']

# %%
# Are feature maps the same across walks?
a = barrier_dataset(**barrier_dataset_config)
b = reg_dataset(**reg_dataset_config)
not np.any(a.feature_maker.feature_map != b.feature_maker.feature_map)
# Out:
# True

# %%
input = barrier_dataset(**barrier_dataset_config)
plt.figure();
plt.plot(input.xs, input.ys)
plt.show()

plt.figure();
states = np.argwhere(input.state_inputs)[:,0]
counts = np.zeros(input.num_states)
for state in np.arange(input.num_states):
    counts[state] = np.sum(states==state)
plt.bar(np.arange(input.num_states), counts)
plt.show()
print(np.median(counts))
np.sum(counts == 0)/input.num_states
# Out:
# 13.0
# 0.0675

# %%
plt.figure()
plt.imshow(input.feature_maker.feature_map)
plt.colorbar()
plt.show()
print(np.sum(input.feature_maker.feature_map)/input.feature_maker.feature_map.size)
# Out:
# 0.11759220962389257

# %%
gamma=0.95

# %%
arena_length = int(np.sqrt(input.num_states)) - 1
walk_xs = input.xs.astype(int)
walk_ys = input.ys.astype(int)

# %% [markdown]
# # Main Option: Use RNN

# %%
rnn = AnalyticSR(
    num_states=input_size, gamma=gamma,
    ca3_kwargs={
        'use_dynamic_lr':False, 'lr':5E-4,
        'rollout':10, 'alpha': 2., 'beta': 2.
        }
    )

reg_outputs, loss, reg_dset = run_rnn(
    '../trained_models/test/', rnn, reg_dataset,
    reg_dataset_config, gamma=gamma, test_over_all=False,
    train_net=False, return_dset=True
    )
rnn.reset()
barrier_outputs, loss, barrier_dset = run_rnn(
    '../trained_models/test/', rnn, barrier_dataset,
    barrier_dataset_config, gamma=gamma, test_over_all=False,
    train_net=False, return_dset=True
    )
# Out:
# [   51] loss: 0.041
# Time per step 0.106s, net 5.291s
#
# [  101] loss: 0.042
# Time per step 0.110s, net 10.796s
#
# [  151] loss: 0.042
# Time per step 0.114s, net 16.484s
#
# [  201] loss: 0.043
# Time per step 0.133s, net 23.121s
#
# [  251] loss: 0.043
# Time per step 0.130s, net 29.633s
#
# [  301] loss: 0.042
# Time per step 0.089s, net 34.101s
#
# [  351] loss: 0.043
# Time per step 0.094s, net 38.777s
#
# [  401] loss: 0.044
# Time per step 0.087s, net 43.115s
#
# [  451] loss: 0.044
# Time per step 0.089s, net 47.559s
#
# [  501] loss: 0.046
# Time per step 0.083s, net 51.700s
#
# [  551] loss: 0.046
# Time per step 0.087s, net 56.061s
#
# [  601] loss: 0.047
# Time per step 0.087s, net 60.419s
#
# [  651] loss: 0.047
# Time per step 0.085s, net 64.693s
#
# [  701] loss: 0.047
# Time per step 0.085s, net 68.944s
#
# [  751] loss: 0.047
# Time per step 0.080s, net 72.957s
#
# [  801] loss: 0.047
# Time per step 0.089s, net 77.402s
#
# [  851] loss: 0.049
# Time per step 0.080s, net 81.416s
#
# [  901] loss: 0.048
# Time per step 0.087s, net 85.759s
#
# [  951] loss: 0.048
# Time per step 0.080s, net 89.751s
#
# [ 1001] loss: 0.048
# Time per step 0.085s, net 94.025s
#
# [ 1051] loss: 0.049
# Time per step 0.087s, net 98.380s
#
# [ 1101] loss: 0.050
# Time per step 0.090s, net 102.864s
#
# [ 1151] loss: 0.049
# Time per step 0.091s, net 107.421s
#
# [ 1201] loss: 0.050
# Time per step 0.094s, net 112.109s
#
# [ 1251] loss: 0.051
# Time per step 0.091s, net 116.677s
#
# [ 1301] loss: 0.052
# Time per step 0.105s, net 121.951s
#
# [ 1351] loss: 0.050
# Time per step 0.101s, net 127.013s
#
# [ 1401] loss: 0.051
# Time per step 0.106s, net 132.294s
#
# [ 1451] loss: 0.050
# Time per step 0.109s, net 137.734s
#
# [ 1501] loss: 0.049
# Time per step 0.109s, net 143.179s
#
# [ 1551] loss: 0.049
# Time per step 0.115s, net 148.913s
#
# [ 1601] loss: 0.051
# Time per step 0.106s, net 154.211s
#
# [ 1651] loss: 0.051
# Time per step 0.107s, net 159.570s
#
# [ 1701] loss: 0.050
# Time per step 0.102s, net 164.661s
#
# [ 1751] loss: 0.050
# Time per step 0.106s, net 169.951s
#
# [ 1801] loss: 0.050
# Time per step 0.103s, net 175.125s
#
# [ 1851] loss: 0.052
# Time per step 0.104s, net 180.332s
#
# [ 1901] loss: 0.051
# Time per step 0.118s, net 186.213s
#
# [ 1951] loss: 0.052
# Time per step 0.095s, net 190.970s
#
# [ 2001] loss: 0.052
# Time per step 0.077s, net 194.809s
#
# [ 2051] loss: 0.051
# Time per step 0.076s, net 198.626s
#
# [ 2101] loss: 0.051
# Time per step 0.078s, net 202.550s
#
# [ 2151] loss: 0.051
# Time per step 0.078s, net 206.474s
#
# [ 2201] loss: 0.053
# Time per step 0.075s, net 210.200s
#
# [ 2251] loss: 0.054
# Time per step 0.077s, net 214.032s
#
# [ 2301] loss: 0.051
# Time per step 0.095s, net 218.784s
#
# [ 2351] loss: 0.053
# Time per step 0.095s, net 223.548s
#
# [ 2401] loss: 0.054
# Time per step 0.092s, net 228.172s
#
# [ 2451] loss: 0.052
# Time per step 0.095s, net 232.938s
#
# [ 2501] loss: 0.051
# Time per step 0.095s, net 237.699s
#
# [ 2551] loss: 0.054
# Time per step 0.096s, net 242.516s
#
# [ 2601] loss: 0.051
# Time per step 0.096s, net 247.327s
#
# [ 2651] loss: 0.053
# Time per step 0.092s, net 251.931s
#
# [ 2701] loss: 0.052
# Time per step 0.081s, net 255.985s
#
# [ 2751] loss: 0.051
# Time per step 0.088s, net 260.397s
#
# [ 2801] loss: 0.053
# Time per step 0.080s, net 264.410s
#
# [ 2851] loss: 0.052
# Time per step 0.094s, net 269.094s
#
# [ 2901] loss: 0.051
# Time per step 0.084s, net 273.311s
#
# [ 2951] loss: 0.051
# Time per step 0.084s, net 277.524s
#
# [ 3001] loss: 0.051
# Time per step 0.088s, net 281.913s
#
# [ 3051] loss: 0.054
# Time per step 0.081s, net 285.976s
#
# [ 3101] loss: 0.050
# Time per step 0.080s, net 289.979s
#
# [ 3151] loss: 0.055
# Time per step 0.082s, net 294.061s
#
# [ 3201] loss: 0.053
# Time per step 0.085s, net 298.299s
#
# [ 3251] loss: 0.052
# Time per step 0.085s, net 302.542s
#
# [ 3301] loss: 0.052
# Time per step 0.083s, net 306.669s
#
# [ 3351] loss: 0.053
# Time per step 0.083s, net 310.816s
#
# [ 3401] loss: 0.054
# Time per step 0.082s, net 314.932s
#
# [ 3451] loss: 0.055
# Time per step 0.091s, net 319.501s
#
# [ 3501] loss: 0.055
# Time per step 0.101s, net 324.568s
#
# [ 3551] loss: 0.053
# Time per step 0.095s, net 329.330s
#
# [ 3601] loss: 0.053
# Time per step 0.093s, net 333.985s
#
# [ 3651] loss: 0.053
# Time per step 0.095s, net 338.752s
#
# [ 3701] loss: 0.053
# Time per step 0.098s, net 343.646s
#
# [ 3751] loss: 0.052
# Time per step 0.083s, net 347.784s
#
# [ 3801] loss: 0.054
# Time per step 0.080s, net 351.806s
#
# [ 3851] loss: 0.054
# Time per step 0.081s, net 355.877s
#
# [ 3901] loss: 0.054
# Time per step 0.078s, net 359.797s
#
# [ 3951] loss: 0.054
# Time per step 0.082s, net 363.883s
#
# [ 4001] loss: 0.053
# Time per step 0.083s, net 368.008s
#
# [ 4051] loss: 0.052
# Time per step 0.089s, net 372.436s
#
# [ 4101] loss: 0.053
# Time per step 0.082s, net 376.522s
#
# [ 4151] loss: 0.053
# Time per step 0.087s, net 380.871s
#
# [ 4201] loss: 0.054
# Time per step 0.085s, net 385.102s
#
# [ 4251] loss: 0.052
# Time per step 0.086s, net 389.414s
#
# [ 4301] loss: 0.053
# Time per step 0.086s, net 393.692s
#
# [ 4351] loss: 0.053
# Time per step 0.071s, net 397.262s
#
# [ 4401] loss: 0.055
# Time per step 0.050s, net 399.744s
#
# [ 4451] loss: 0.053
# Time per step 0.050s, net 402.239s
#
# [ 4501] loss: 0.053
# Time per step 0.053s, net 404.894s
#
# [ 4551] loss: 0.056
# Time per step 0.051s, net 407.424s
#
# [ 4601] loss: 0.056
# Time per step 0.050s, net 409.933s
#
# [ 4651] loss: 0.054
# Time per step 0.051s, net 412.467s
#
# [ 4701] loss: 0.056
# Time per step 0.051s, net 415.025s
#
# [ 4751] loss: 0.057
# Time per step 0.050s, net 417.533s
#
# [ 4801] loss: 0.057
# Time per step 0.050s, net 420.014s
#
# [ 4851] loss: 0.056
# Time per step 0.049s, net 422.488s
#
# [ 4901] loss: 0.056
# Time per step 0.050s, net 424.985s
#
# [ 4951] loss: 0.058
# Time per step 0.049s, net 427.436s
#
# [ 5001] loss: 0.057
# Time per step 0.066s, net 430.714s
#
# [ 5051] loss: 0.056
# Time per step 0.059s, net 433.642s
#
# [ 5101] loss: 0.057
# Time per step 0.085s, net 437.897s
#
# [ 5151] loss: 0.058
# Time per step 0.057s, net 440.729s
#
# [ 5201] loss: 0.060
# Time per step 0.078s, net 444.620s
#
# [ 5251] loss: 0.059
# Time per step 0.092s, net 449.206s
#
# [ 5301] loss: 0.059
# Time per step 0.071s, net 452.764s
#
# [ 5351] loss: 0.063
# Time per step 0.048s, net 455.152s
#
# [ 5401] loss: 0.062
# Time per step 0.035s, net 456.899s
#
# [ 5451] loss: 0.061
# Time per step 0.034s, net 458.590s
#
# [ 5501] loss: 0.059
# Time per step 0.050s, net 461.084s
#
# [ 5551] loss: 0.059
# Time per step 0.054s, net 463.767s
#
# [ 5601] loss: 0.057
# Time per step 0.064s, net 466.966s
#
# [ 5651] loss: 0.056
# Time per step 0.052s, net 469.558s
#
# [ 5701] loss: 0.055
# Time per step 0.051s, net 472.129s
#
# [ 5751] loss: 0.057
# Time per step 0.053s, net 474.789s
#
# [ 5801] loss: 0.059
# Time per step 0.049s, net 477.244s
#
# [ 5851] loss: 0.058
# Time per step 0.048s, net 479.657s
#
# [ 5901] loss: 0.061
# Time per step 0.047s, net 482.009s
#
# [ 5951] loss: 0.058
# Time per step 0.041s, net 484.051s
# Finished Training
#
#
# [   51] loss: 0.047
# Time per step 0.028s, net 1.423s
#
# [  101] loss: 0.042
# Time per step 0.030s, net 2.936s
#
# [  151] loss: 0.044
# Time per step 0.037s, net 4.770s
#
# [  201] loss: 0.043
# Time per step 0.033s, net 6.435s
#
# [  251] loss: 0.043
# Time per step 0.030s, net 7.921s
#
# [  301] loss: 0.043
# Time per step 0.029s, net 9.366s
#
# [  351] loss: 0.043
# Time per step 0.029s, net 10.823s
#
# [  401] loss: 0.043
# Time per step 0.032s, net 12.426s
#
# [  451] loss: 0.043
# Time per step 0.029s, net 13.877s
#
# [  501] loss: 0.044
# Time per step 0.029s, net 15.328s
#
# [  551] loss: 0.043
# Time per step 0.029s, net 16.771s
#
# [  601] loss: 0.044
# Time per step 0.029s, net 18.218s
#
# [  651] loss: 0.044
# Time per step 0.029s, net 19.664s
#
# [  701] loss: 0.044
# Time per step 0.030s, net 21.151s
#
# [  751] loss: 0.044
# Time per step 0.029s, net 22.605s
#
# [  801] loss: 0.044
# Time per step 0.029s, net 24.055s
#
# [  851] loss: 0.044
# Time per step 0.029s, net 25.507s
#
# [  901] loss: 0.044
# Time per step 0.029s, net 26.955s
#
# [  951] loss: 0.044
# Time per step 0.031s, net 28.505s
#
# [ 1001] loss: 0.043
# Time per step 0.033s, net 30.154s
#
# [ 1051] loss: 0.043
# Time per step 0.030s, net 31.636s
#
# [ 1101] loss: 0.044
# Time per step 0.029s, net 33.089s
#
# [ 1151] loss: 0.043
# Time per step 0.031s, net 34.658s
#
# [ 1201] loss: 0.043
# Time per step 0.030s, net 36.166s
#
# [ 1251] loss: 0.044
# Time per step 0.029s, net 37.619s
#
# [ 1301] loss: 0.042
# Time per step 0.030s, net 39.103s
#
# [ 1351] loss: 0.042
# Time per step 0.031s, net 40.665s
#
# [ 1401] loss: 0.044
# Time per step 0.032s, net 42.244s
# [ 1451] loss: 0.045
# Time per step 0.045s, net 44.500s
#
# [ 1501] loss: 0.047
# Time per step 0.028s, net 45.886s
#
# [ 1551] loss: 0.044
# Time per step 0.028s, net 47.305s
#
# [ 1601] loss: 0.044
# Time per step 0.029s, net 48.734s
#
# [ 1651] loss: 0.046
# Time per step 0.030s, net 50.213s
#
# [ 1701] loss: 0.046
# Time per step 0.032s, net 51.806s
#
# [ 1751] loss: 0.045
# Time per step 0.031s, net 53.381s
#
# [ 1801] loss: 0.046
# Time per step 0.032s, net 54.982s
#
# [ 1851] loss: 0.046
# Time per step 0.031s, net 56.509s
#
# [ 1901] loss: 0.048
# Time per step 0.032s, net 58.112s
#
# [ 1951] loss: 0.049
# Time per step 0.052s, net 60.735s
#
# [ 2001] loss: 0.048
# Time per step 0.053s, net 63.395s
#
# [ 2051] loss: 0.049
# Time per step 0.071s, net 66.942s
#
# [ 2101] loss: 0.047
# Time per step 0.064s, net 70.138s
#
# [ 2151] loss: 0.048
# Time per step 0.054s, net 72.836s
#
# [ 2201] loss: 0.049
# Time per step 0.058s, net 75.743s
#
# [ 2251] loss: 0.047
# Time per step 0.054s, net 78.467s
#
# [ 2301] loss: 0.047
# Time per step 0.056s, net 81.286s
#
# [ 2351] loss: 0.048
# Time per step 0.058s, net 84.181s
#
# [ 2401] loss: 0.048
# Time per step 0.066s, net 87.505s
#
# [ 2451] loss: 0.048
# Time per step 0.059s, net 90.446s
#
# [ 2501] loss: 0.048
# Time per step 0.091s, net 94.977s
#
# [ 2551] loss: 0.046
# Time per step 0.115s, net 100.725s
#
# [ 2601] loss: 0.048
# Time per step 0.122s, net 106.828s
#
# [ 2651] loss: 0.048
# Time per step 0.142s, net 113.913s
#
# [ 2701] loss: 0.048
# Time per step 0.121s, net 119.987s
#
# [ 2751] loss: 0.049
# Time per step 0.131s, net 126.522s
#
# [ 2801] loss: 0.048
# Time per step 0.110s, net 132.017s
#
# [ 2851] loss: 0.049
# Time per step 0.102s, net 137.120s
#
# [ 2901] loss: 0.050
# Time per step 0.107s, net 142.449s
#
# [ 2951] loss: 0.048
# Time per step 0.110s, net 147.966s
#
# [ 3001] loss: 0.047
# Time per step 0.112s, net 153.552s
#
# [ 3051] loss: 0.048
# Time per step 0.099s, net 158.518s
#
# [ 3101] loss: 0.048
# Time per step 0.105s, net 163.743s
#
# [ 3151] loss: 0.047
# Time per step 0.106s, net 169.068s
#
# [ 3201] loss: 0.047
# Time per step 0.120s, net 175.043s
#
# [ 3251] loss: 0.049
# Time per step 0.110s, net 180.558s
#
# [ 3301] loss: 0.049
# Time per step 0.115s, net 186.321s
#
# [ 3351] loss: 0.049
# Time per step 0.098s, net 191.207s
#
# [ 3401] loss: 0.047
# Time per step 0.098s, net 196.117s
#
# [ 3451] loss: 0.048
# Time per step 0.102s, net 201.230s
#
# [ 3501] loss: 0.049
# Time per step 0.094s, net 205.951s
#
# [ 3551] loss: 0.049
# Time per step 0.086s, net 210.259s
#
# [ 3601] loss: 0.048
# Time per step 0.094s, net 214.960s
#
# [ 3651] loss: 0.047
# Time per step 0.084s, net 219.171s
#
# [ 3701] loss: 0.050
# Time per step 0.085s, net 223.444s
#
# [ 3751] loss: 0.049
# Time per step 0.085s, net 227.703s
#
# [ 3801] loss: 0.047
# Time per step 0.082s, net 231.824s
#
# [ 3851] loss: 0.050
# Time per step 0.100s, net 236.842s
#
# [ 3901] loss: 0.049
# Time per step 0.087s, net 241.210s
#
# [ 3951] loss: 0.050
# Time per step 0.084s, net 245.413s
#
# [ 4001] loss: 0.050
# Time per step 0.091s, net 249.964s
#
# [ 4051] loss: 0.051
# Time per step 0.099s, net 254.917s
#
# [ 4101] loss: 0.050
# Time per step 0.096s, net 259.713s
#
# [ 4151] loss: 0.053
# Time per step 0.104s, net 264.914s
#
# [ 4201] loss: 0.054
# Time per step 0.113s, net 270.547s
#
# [ 4251] loss: 0.054
# Time per step 0.108s, net 275.934s
#
# [ 4301] loss: 0.054
# Time per step 0.111s, net 281.480s
#
# [ 4351] loss: 0.054
# Time per step 0.103s, net 286.654s
#
# [ 4401] loss: 0.058
# Time per step 0.105s, net 291.905s
#
# [ 4451] loss: 0.057
# Time per step 0.110s, net 297.399s
#
# [ 4501] loss: 0.054
# Time per step 0.104s, net 302.622s
#
# [ 4551] loss: 0.054
# Time per step 0.100s, net 307.641s
#
# [ 4601] loss: 0.051
# Time per step 0.098s, net 312.525s
#
# [ 4651] loss: 0.051
# Time per step 0.098s, net 317.428s
#
# [ 4701] loss: 0.051
# Time per step 0.095s, net 322.203s
#
# [ 4751] loss: 0.052
# Time per step 0.093s, net 326.830s
#
# [ 4801] loss: 0.049
# Time per step 0.103s, net 331.974s
#
# [ 4851] loss: 0.051
# Time per step 0.093s, net 336.624s
#
# [ 4901] loss: 0.050
# Time per step 0.096s, net 341.431s
#
# [ 4951] loss: 0.050
# Time per step 0.117s, net 347.261s
#
# [ 5001] loss: 0.050
# Time per step 0.144s, net 354.472s
#
# [ 5051] loss: 0.049
# Time per step 0.101s, net 359.515s
#
# [ 5101] loss: 0.050
# Time per step 0.112s, net 365.109s
#
# [ 5151] loss: 0.050
# Time per step 0.098s, net 370.028s
#
# [ 5201] loss: 0.050
# Time per step 0.096s, net 374.820s
#
# [ 5251] loss: 0.050
# Time per step 0.106s, net 380.115s
#
# [ 5301] loss: 0.052
# Time per step 0.107s, net 385.452s
#
# [ 5351] loss: 0.049
# Time per step 0.108s, net 390.864s
#
# [ 5401] loss: 0.051
# Time per step 0.120s, net 396.882s
#
# [ 5451] loss: 0.050
# Time per step 0.116s, net 402.701s
#
# [ 5501] loss: 0.051
# Time per step 0.128s, net 409.104s
#
# [ 5551] loss: 0.050
# Time per step 0.106s, net 414.427s
#
# [ 5601] loss: 0.053
# Time per step 0.115s, net 420.153s
#
# [ 5651] loss: 0.052
# Time per step 0.131s, net 426.726s
#
# [ 5701] loss: 0.051
# Time per step 0.105s, net 431.953s
#
# [ 5751] loss: 0.052
# Time per step 0.106s, net 437.237s
#
# [ 5801] loss: 0.052
# Time per step 0.122s, net 443.335s
#
# [ 5851] loss: 0.052
# Time per step 0.133s, net 449.989s
#
# [ 5901] loss: 0.052
# Time per step 0.117s, net 455.861s
#
# [ 5951] loss: 0.051
# Time per step 0.107s, net 461.186s
# Finished Training

# %% [markdown]
# # Debug Option: Run MLP

# %%
rnn = MLP(input_size, input_size*2)

reg_outputs, loss, reg_dset = run_mlp(
    '../trained_models/test/', rnn, reg_dataset,
    reg_dataset_config, gamma=gamma, test_over_all=False,
    return_dset=True
    )
rnn.reset()
barrier_outputs, loss, barrier_dset = run_mlp(
    '../trained_models/test/', rnn, barrier_dataset,
    barrier_dataset_config, gamma=gamma, test_over_all=False,
    return_dset=True
    )
# Out:
# [   51] loss: 0.043
# Time per step 0.006s, net 0.318s
#
# [  101] loss: 0.026
# Time per step 0.009s, net 0.745s
#
# [  151] loss: 0.026
# Time per step 0.010s, net 1.242s
#
# [  201] loss: 0.027
# Time per step 0.010s, net 1.752s
#
# [  251] loss: 0.028
# Time per step 0.011s, net 2.294s
#
# [  301] loss: 0.027
# Time per step 0.014s, net 3.006s
#
# [  351] loss: 0.027
# Time per step 0.011s, net 3.579s
#
# [  401] loss: 0.026
# Time per step 0.012s, net 4.168s
#
# [  451] loss: 0.026
# Time per step 0.013s, net 4.838s
#
# [  501] loss: 0.026
# Time per step 0.013s, net 5.481s
#
# [  551] loss: 0.027
# Time per step 0.015s, net 6.214s
#
# [  601] loss: 0.027
# Time per step 0.015s, net 6.976s
#
# [  651] loss: 0.027
# Time per step 0.016s, net 7.792s
#
# [  701] loss: 0.028
# Time per step 0.017s, net 8.652s
#
# [  751] loss: 0.028
# Time per step 0.018s, net 9.544s
#
# [  801] loss: 0.028
# Time per step 0.018s, net 10.461s
#
# [  851] loss: 0.029
# Time per step 0.019s, net 11.428s
#
# [  901] loss: 0.029
# Time per step 0.020s, net 12.435s
#
# [  951] loss: 0.029
# Time per step 0.020s, net 13.447s
#
# [ 1001] loss: 0.029
# Time per step 0.021s, net 14.518s
#
# [ 1051] loss: 0.029
# Time per step 0.022s, net 15.614s
#
# [ 1101] loss: 0.030
# Time per step 0.022s, net 16.730s
#
# [ 1151] loss: 0.030
# Time per step 0.023s, net 17.896s
#
# [ 1201] loss: 0.030
# Time per step 0.024s, net 19.099s
#
# [ 1251] loss: 0.031
# Time per step 0.025s, net 20.358s
#
# [ 1301] loss: 0.030
# Time per step 0.026s, net 21.638s
#
# [ 1351] loss: 0.031
# Time per step 0.026s, net 22.962s
#
# [ 1401] loss: 0.031
# Time per step 0.037s, net 24.809s
#
# [ 1451] loss: 0.031
# Time per step 0.034s, net 26.494s
#
# [ 1501] loss: 0.031
# Time per step 0.031s, net 28.042s
#
# [ 1551] loss: 0.032
# Time per step 0.029s, net 29.486s
#
# [ 1601] loss: 0.031
# Time per step 0.030s, net 30.981s
#
# [ 1651] loss: 0.031
# Time per step 0.037s, net 32.843s
#
# [ 1701] loss: 0.031
# Time per step 0.035s, net 34.599s
#
# [ 1751] loss: 0.031
# Time per step 0.041s, net 36.674s
#
# [ 1801] loss: 0.031
# Time per step 0.040s, net 38.685s
#
# [ 1851] loss: 0.031
# Time per step 0.038s, net 40.568s
#
# [ 1901] loss: 0.031
# Time per step 0.034s, net 42.260s
#
# [ 1951] loss: 0.032
# Time per step 0.041s, net 44.327s
#
# [ 2001] loss: 0.032
# Time per step 0.045s, net 46.565s
#
# [ 2051] loss: 0.032
# Time per step 0.048s, net 48.952s
#
# [ 2101] loss: 0.032
# Time per step 0.050s, net 51.475s
#
# [ 2151] loss: 0.032
# Time per step 0.045s, net 53.740s
#
# [ 2201] loss: 0.032
# Time per step 0.049s, net 56.181s
#
# [ 2251] loss: 0.032
# Time per step 0.048s, net 58.589s
#
# [ 2301] loss: 0.032
# Time per step 0.045s, net 60.827s
#
# [ 2351] loss: 0.032
# Time per step 0.046s, net 63.150s
#
# [ 2401] loss: 0.032
# Time per step 0.043s, net 65.293s
#
# [ 2451] loss: 0.032
# Time per step 0.042s, net 67.398s
#
# [ 2501] loss: 0.032
# Time per step 0.052s, net 70.005s
#
# [ 2551] loss: 0.032
# Time per step 0.046s, net 72.295s
#
# [ 2601] loss: 0.032
# Time per step 0.063s, net 75.458s
#
# [ 2651] loss: 0.032
# Time per step 0.073s, net 79.125s
#
# [ 2701] loss: 0.032
# Time per step 0.089s, net 83.597s
#
# [ 2751] loss: 0.032
# Time per step 0.078s, net 87.515s
#
# [ 2801] loss: 0.032
# Time per step 0.099s, net 92.444s
#
# [ 2851] loss: 0.032
# Time per step 0.055s, net 95.176s
#
# [ 2901] loss: 0.032
# Time per step 0.052s, net 97.778s
#
# [ 2951] loss: 0.031
# Time per step 0.055s, net 100.534s
#
# [ 3001] loss: 0.032
# Time per step 0.054s, net 103.224s
#
# [ 3051] loss: 0.031
# Time per step 0.045s, net 105.484s
#
# [ 3101] loss: 0.031
# Time per step 0.045s, net 107.754s
#
# [ 3151] loss: 0.032
# Time per step 0.046s, net 110.032s
#
# [ 3201] loss: 0.032
# Time per step 0.047s, net 112.360s
#
# [ 3251] loss: 0.032
# Time per step 0.051s, net 114.930s
#
# [ 3301] loss: 0.032
# Time per step 0.057s, net 117.759s
#
# [ 3351] loss: 0.032
# Time per step 0.075s, net 121.521s
#
# [ 3401] loss: 0.032
# Time per step 0.061s, net 124.547s
#
# [ 3451] loss: 0.032
# Time per step 0.059s, net 127.520s
#
# [ 3501] loss: 0.032
# Time per step 0.058s, net 130.414s
#
# [ 3551] loss: 0.032
# Time per step 0.066s, net 133.690s
#
# [ 3601] loss: 0.032
# Time per step 0.060s, net 136.696s
#
# [ 3651] loss: 0.032
# Time per step 0.063s, net 139.837s
#
# [ 3701] loss: 0.032
# Time per step 0.065s, net 143.110s
#
# [ 3751] loss: 0.032
# Time per step 0.072s, net 146.720s
#
# [ 3801] loss: 0.032
# Time per step 0.066s, net 150.011s
#
# [ 3851] loss: 0.032
# Time per step 0.068s, net 153.421s
#
# [ 3901] loss: 0.032
# Time per step 0.067s, net 156.751s
#
# [ 3951] loss: 0.032
# Time per step 0.072s, net 160.349s
#
# [ 4001] loss: 0.032
# Time per step 0.070s, net 163.872s
#
# [ 4051] loss: 0.032
# Time per step 0.071s, net 167.420s
#
# [ 4101] loss: 0.032
# Time per step 0.072s, net 171.044s
#
# [ 4151] loss: 0.032
# Time per step 0.071s, net 174.584s
#
# [ 4201] loss: 0.032
# Time per step 0.070s, net 178.099s
#
# [ 4251] loss: 0.032
# Time per step 0.070s, net 181.605s
#
# [ 4301] loss: 0.032
# Time per step 0.086s, net 185.918s
#
# [ 4351] loss: 0.032
# Time per step 0.071s, net 189.490s
#
# [ 4401] loss: 0.032
# Time per step 0.073s, net 193.149s
#
# [ 4451] loss: 0.032
# Time per step 0.077s, net 196.997s
#
# [ 4501] loss: 0.032
# Time per step 0.074s, net 200.707s
#
# [ 4551] loss: 0.032
# Time per step 0.075s, net 204.454s
#
# [ 4601] loss: 0.032
# Time per step 0.076s, net 208.264s
#
# [ 4651] loss: 0.032
# Time per step 0.078s, net 212.149s
#
# [ 4701] loss: 0.032
# Time per step 0.080s, net 216.173s
#
# [ 4751] loss: 0.032
# Time per step 0.077s, net 220.029s
#
# [ 4801] loss: 0.032
# Time per step 0.079s, net 223.998s
#
# [ 4851] loss: 0.032
# Time per step 0.082s, net 228.088s
#
# [ 4901] loss: 0.032
# Time per step 0.081s, net 232.124s
#
# [ 4951] loss: 0.032
# Time per step 0.081s, net 236.160s
#
# [ 5001] loss: 0.032
# Time per step 0.082s, net 240.237s
#
# [ 5051] loss: 0.032
# Time per step 0.082s, net 244.340s
#
# [ 5101] loss: 0.032
# Time per step 0.099s, net 249.300s
#
# [ 5151] loss: 0.032
# Time per step 0.080s, net 253.304s
#
# [ 5201] loss: 0.032
# Time per step 0.082s, net 257.382s
#
# [ 5251] loss: 0.032
# Time per step 0.082s, net 261.491s
#
# [ 5301] loss: 0.032
# Time per step 0.082s, net 265.594s
#
# [ 5351] loss: 0.032
# Time per step 0.082s, net 269.693s
#
# [ 5401] loss: 0.032
# Time per step 0.082s, net 273.776s
#
# [ 5451] loss: 0.032
# Time per step 0.083s, net 277.903s
#
# [ 5501] loss: 0.032
# Time per step 0.085s, net 282.169s
#
# [ 5551] loss: 0.032
# Time per step 0.082s, net 286.269s
#
# [ 5601] loss: 0.032
# Time per step 0.085s, net 290.505s
#
# [ 5651] loss: 0.032
# Time per step 0.083s, net 294.639s
#
# [ 5701] loss: 0.032
# Time per step 0.083s, net 298.790s
#
# [ 5751] loss: 0.032
# Time per step 0.083s, net 302.952s
#
# [ 5801] loss: 0.032
# Time per step 0.076s, net 306.730s
#
# [ 5851] loss: 0.032
# Time per step 0.074s, net 310.447s
#
# [ 5901] loss: 0.032
# Time per step 0.078s, net 314.340s
#
# [ 5951] loss: 0.032
# Time per step 0.075s, net 318.087s
# Finished Training
#
#
# [   51] loss: 0.019
# Time per step 0.007s, net 0.356s
#
# [  101] loss: 0.017
# Time per step 0.009s, net 0.781s
#
# [  151] loss: 0.017
# Time per step 0.009s, net 1.254s
#
# [  201] loss: 0.017
# Time per step 0.010s, net 1.754s
#
# [  251] loss: 0.019
# Time per step 0.010s, net 2.272s
#
# [  301] loss: 0.022
# Time per step 0.012s, net 2.855s
#
# [  351] loss: 0.024
# Time per step 0.012s, net 3.451s
#
# [  401] loss: 0.025
# Time per step 0.012s, net 4.068s
#
# [  451] loss: 0.024
# Time per step 0.014s, net 4.746s
#
# [  501] loss: 0.025
# Time per step 0.015s, net 5.473s
#
# [  551] loss: 0.026
# Time per step 0.015s, net 6.215s
#
# [  601] loss: 0.027
# Time per step 0.016s, net 7.019s
#
# [  651] loss: 0.027
# Time per step 0.017s, net 7.864s
#
# [  701] loss: 0.026
# Time per step 0.017s, net 8.720s
#
# [  751] loss: 0.027
# Time per step 0.018s, net 9.618s
#
# [  801] loss: 0.028
# Time per step 0.019s, net 10.557s
#
# [  851] loss: 0.029
# Time per step 0.020s, net 11.540s
#
# [  901] loss: 0.029
# Time per step 0.020s, net 12.551s
#
# [  951] loss: 0.030
# Time per step 0.022s, net 13.632s
#
# [ 1001] loss: 0.030
# Time per step 0.022s, net 14.732s
#
# [ 1051] loss: 0.030
# Time per step 0.023s, net 15.860s
#
# [ 1101] loss: 0.030
# Time per step 0.023s, net 17.030s
#
# [ 1151] loss: 0.030
# Time per step 0.024s, net 18.250s
#
# [ 1201] loss: 0.030
# Time per step 0.025s, net 19.499s
#
# [ 1251] loss: 0.030
# Time per step 0.026s, net 20.797s
#
# [ 1301] loss: 0.030
# Time per step 0.027s, net 22.151s
#
# [ 1351] loss: 0.030
# Time per step 0.042s, net 24.271s
#
# [ 1401] loss: 0.029
# Time per step 0.027s, net 25.640s
#
# [ 1451] loss: 0.030
# Time per step 0.029s, net 27.080s
#
# [ 1501] loss: 0.031
# Time per step 0.029s, net 28.547s
# [ 1551] loss: 0.031
# Time per step 0.031s, net 30.076s
#
# [ 1601] loss: 0.031
# Time per step 0.031s, net 31.647s
#
# [ 1651] loss: 0.031
# Time per step 0.033s, net 33.308s
#
# [ 1701] loss: 0.031
# Time per step 0.033s, net 34.962s
#
# [ 1751] loss: 0.031
# Time per step 0.034s, net 36.657s
#
# [ 1801] loss: 0.031
# Time per step 0.035s, net 38.403s
#
# [ 1851] loss: 0.031
# Time per step 0.036s, net 40.186s
#
# [ 1901] loss: 0.031
# Time per step 0.036s, net 42.001s
#
# [ 1951] loss: 0.031
# Time per step 0.045s, net 44.255s
#
# [ 2001] loss: 0.031
# Time per step 0.038s, net 46.160s
#
# [ 2051] loss: 0.031
# Time per step 0.050s, net 48.661s
#
# [ 2101] loss: 0.031
# Time per step 0.051s, net 51.212s
#
# [ 2151] loss: 0.031
# Time per step 0.060s, net 54.203s
#
# [ 2201] loss: 0.031
# Time per step 0.078s, net 58.102s
#
# [ 2251] loss: 0.031
# Time per step 0.042s, net 60.225s
#
# [ 2301] loss: 0.031
# Time per step 0.041s, net 62.279s
#
# [ 2351] loss: 0.031
# Time per step 0.043s, net 64.412s
#
# [ 2401] loss: 0.031
# Time per step 0.043s, net 66.567s
#
# [ 2451] loss: 0.031
# Time per step 0.047s, net 68.936s
#
# [ 2501] loss: 0.031
# Time per step 0.052s, net 71.522s
#
# [ 2551] loss: 0.031
# Time per step 0.066s, net 74.834s
#
# [ 2601] loss: 0.031
# Time per step 0.046s, net 77.134s
#
# [ 2651] loss: 0.030
# Time per step 0.047s, net 79.485s
#
# [ 2701] loss: 0.030
# Time per step 0.052s, net 82.064s
#
# [ 2751] loss: 0.030
# Time per step 0.049s, net 84.528s
#
# [ 2801] loss: 0.030
# Time per step 0.062s, net 87.626s
#
# [ 2851] loss: 0.030
# Time per step 0.058s, net 90.540s
#
# [ 2901] loss: 0.030
# Time per step 0.051s, net 93.098s
#
# [ 2951] loss: 0.030
# Time per step 0.067s, net 96.473s
#
# [ 3001] loss: 0.031
# Time per step 0.074s, net 100.177s
#
# [ 3051] loss: 0.031
# Time per step 0.079s, net 104.135s
#
# [ 3101] loss: 0.031
# Time per step 0.067s, net 107.467s
#
# [ 3151] loss: 0.031
# Time per step 0.061s, net 110.516s
#
# [ 3201] loss: 0.031
# Time per step 0.056s, net 113.316s
#
# [ 3251] loss: 0.031
# Time per step 0.060s, net 116.294s
#
# [ 3301] loss: 0.031
# Time per step 0.066s, net 119.576s
#
# [ 3351] loss: 0.031
# Time per step 0.060s, net 122.575s
#
# [ 3401] loss: 0.031
# Time per step 0.067s, net 125.927s
#
# [ 3451] loss: 0.031
# Time per step 0.076s, net 129.744s
#
# [ 3501] loss: 0.031
# Time per step 0.060s, net 132.720s
#
# [ 3551] loss: 0.031
# Time per step 0.061s, net 135.756s
#
# [ 3601] loss: 0.031
# Time per step 0.059s, net 138.726s
#
# [ 3651] loss: 0.031
# Time per step 0.061s, net 141.757s
#
# [ 3701] loss: 0.031
# Time per step 0.061s, net 144.831s
#
# [ 3751] loss: 0.031
# Time per step 0.064s, net 148.025s
#
# [ 3801] loss: 0.031
# Time per step 0.076s, net 151.816s
#
# [ 3851] loss: 0.031
# Time per step 0.065s, net 155.062s
#
# [ 3901] loss: 0.031
# Time per step 0.066s, net 158.364s
#
# [ 3951] loss: 0.031
# Time per step 0.067s, net 161.731s
#
# [ 4001] loss: 0.031
# Time per step 0.069s, net 165.195s
#
# [ 4051] loss: 0.031
# Time per step 0.069s, net 168.641s
#
# [ 4101] loss: 0.031
# Time per step 0.069s, net 172.102s
#
# [ 4151] loss: 0.031
# Time per step 0.070s, net 175.596s
#
# [ 4201] loss: 0.031
# Time per step 0.072s, net 179.174s
#
# [ 4251] loss: 0.031
# Time per step 0.076s, net 182.966s
#
# [ 4301] loss: 0.031
# Time per step 0.073s, net 186.600s
#
# [ 4351] loss: 0.031
# Time per step 0.074s, net 190.296s
#
# [ 4401] loss: 0.031
# Time per step 0.075s, net 194.044s
#
# [ 4451] loss: 0.031
# Time per step 0.076s, net 197.820s
#
# [ 4501] loss: 0.031
# Time per step 0.077s, net 201.660s
#
# [ 4551] loss: 0.031
# Time per step 0.080s, net 205.676s
#
# [ 4601] loss: 0.031
# Time per step 0.077s, net 209.548s
#
# [ 4651] loss: 0.031
# Time per step 0.078s, net 213.443s
#
# [ 4701] loss: 0.031
# Time per step 0.082s, net 217.528s
#
# [ 4751] loss: 0.031
# Time per step 0.080s, net 221.536s
#
# [ 4801] loss: 0.031
# Time per step 0.080s, net 225.537s
#
# [ 4851] loss: 0.031
# Time per step 0.081s, net 229.576s
#
# [ 4901] loss: 0.031
# Time per step 0.082s, net 233.683s
#
# [ 4951] loss: 0.031
# Time per step 0.086s, net 238.005s
#
# [ 5001] loss: 0.031
# Time per step 0.083s, net 242.159s
#
# [ 5051] loss: 0.031
# Time per step 0.087s, net 246.510s
#
# [ 5101] loss: 0.031
# Time per step 0.083s, net 250.665s
#
# [ 5151] loss: 0.031
# Time per step 0.083s, net 254.822s
#
# [ 5201] loss: 0.031
# Time per step 0.086s, net 259.125s
#
# [ 5251] loss: 0.031
# Time per step 0.086s, net 263.416s
#
# [ 5301] loss: 0.031
# Time per step 0.087s, net 267.753s
#
# [ 5351] loss: 0.031
# Time per step 0.085s, net 272.025s
#
# [ 5401] loss: 0.031
# Time per step 0.086s, net 276.318s
#
# [ 5451] loss: 0.032
# Time per step 0.089s, net 280.752s
#
# [ 5501] loss: 0.032
# Time per step 0.086s, net 285.033s
#
# [ 5551] loss: 0.031
# Time per step 0.086s, net 289.310s
#
# [ 5601] loss: 0.032
# Time per step 0.086s, net 293.590s
#
# [ 5651] loss: 0.032
# Time per step 0.086s, net 297.870s
#
# [ 5701] loss: 0.032
# Time per step 0.086s, net 302.154s
#
# [ 5751] loss: 0.032
# Time per step 0.086s, net 306.431s
#
# [ 5801] loss: 0.032
# Time per step 0.088s, net 310.842s
#
# [ 5851] loss: 0.032
# Time per step 0.085s, net 315.102s
#
# [ 5901] loss: 0.031
# Time per step 0.086s, net 319.384s
#
# [ 5951] loss: 0.031
# Time per step 0.086s, net 323.671s
# Finished Training

# %% [markdown]
# # Check Similarity Across Walks

# %%
from scipy.stats import pearsonr
import seaborn as sns
import pandas as pd

# %%
barrier_xs = barrier_dset.xs
barrier_ys = barrier_dset.ys
reg_xs = reg_dset.xs
reg_ys = reg_dset.ys
arena_length = int(np.sqrt(barrier_dset.num_states))

# %%
barrier_locs = []
wall = arena_length//2
for x in [wall-2, wall-1, wall, wall+1]:
    for y in np.arange(min(7, wall+1)):
        barrier_locs.append(x*arena_length + y)

# %%
corrs = []
condn = []
barrier_neurs = []

for neur in np.arange(barrier_outputs.shape[1]):
    barrier_field = np.zeros((arena_length, arena_length))
    reg_field = np.zeros((arena_length, arena_length))
    for field_x in range(arena_length):
        for field_y in range(arena_length):
            barrier_frame_idxs = np.logical_and(
                barrier_xs == field_x, barrier_ys == field_y
                )
            barrier_field[field_x, field_y] = np.nanmean(
                barrier_outputs[barrier_frame_idxs, neur]
                )
            barrier_field[np.isnan(barrier_field)] = 0

            reg_frame_idxs = np.logical_and(
                reg_xs == field_x, reg_ys == field_y
                )
            reg_field[field_x, field_y] = np.nanmean(
                reg_outputs[reg_frame_idxs, neur]
                )
            reg_field[np.isnan(reg_field)] = 0
    if barrier_field.max() > 0:
        barrier_field /= barrier_field.max()
    if reg_field.max() > 0:
        reg_field /= reg_field.max()

    r, _ = pearsonr(barrier_field.flatten(), reg_field.flatten())
    fisher_r = np.arctanh(r)

    corrs.append(fisher_r)
    
    is_near = False
    #if np.argmax(reg_field.flatten()) in barrier_locs:
    if np.any(reg_field.flatten()[barrier_locs] > reg_field.max()*0.8):
        is_near = True
        barrier_neurs.append(neur)
#     for barrier_loc in barrier_locs:
#         barrier_feature = reg_dset.feature_maker.feature_map[:,barrier_loc]
#         if barrier_feature[neur] > 0.5:
#             is_near = True
    if is_near:
        condn.append('Near')
    else:
        condn.append('Far')
corrs = np.array(corrs)
condn = np.array(condn)
# Out:
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: Mean of empty slice

# %%
fig, ax = plt.subplots(figsize=(6.4*0.5, 4.8))
df = pd.DataFrame({'Spatial Similarity': corrs, 'Condition': condn})
sns.barplot(
    x='Condition', y='Spatial Similarity', data=df, ax=ax,
    palette=['lightgrey', 'dimgray']
    )
# plt.ylim(0, 1.7)
# plt.plot([0, 0, 1, 1], [1.4, 1.5, 1.5, 1.4], lw=1.5, c='k')
# plt.text((0+1)/2, 1.5, "***", ha='center', va='bottom', color='k')
plt.xlabel('Condition', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Spatial Similarity', fontsize=16)
plt.show()

# %%
from scipy.stats import ranksums
ranksums(corrs[condn=='Far'], corrs[condn=='Near'])
# Out:
# RanksumsResult(statistic=-0.4092572075254313, pvalue=0.6823509157913141)

# %% [markdown]
# # Make Plots

# %%
walk_xs = barrier_dset.xs
walk_ys = barrier_dset.ys
arena_length = int(np.sqrt(barrier_dset.num_states))

# %%
import matplotlib.gridspec as gridspec

grid_x = 4; grid_y = 4;

plt.figure(figsize = (6, 6))
gs1 = gridspec.GridSpec(grid_x, grid_y)
gs1.update(wspace=0.05, hspace=0.05) # set the spacing between axes. 

neurs = np.array(barrier_neurs)
np.random.shuffle(neurs)

idx = 0
for neur in neurs:
    firing_field = np.zeros((arena_length, arena_length))*np.nan
    for x in range(arena_length):
        for y in range(arena_length):
            frame_idxs = np.logical_and(barrier_xs == x, barrier_ys == y)
            fr = np.nanmean(barrier_outputs[frame_idxs, neur])
            firing_field[x,y] = fr
    firing_field[np.isnan(firing_field)] = 0    
    if not np.any(firing_field > 0): continue
    ax = plt.subplot(gs1[idx])
    plt.axis('on')
    ax.imshow(firing_field/firing_field.max(), vmin=0, vmax=1)
    ax.plot([-0.5, arena_length/2], [arena_length//2 -1, arena_length//2 -1], 'red', linewidth=3)
    ax.set_xticks([])
    ax.set_yticks([])
    
    idx += 1
    if idx == grid_x*grid_y: break
plt.show()
# Out:
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: Mean of empty slice

# %%
import matplotlib.gridspec as gridspec

grid_x = 4; grid_y = 4;

plt.figure(figsize = (6, 6))
gs1 = gridspec.GridSpec(grid_x, grid_y)
gs1.update(wspace=0.05, hspace=0.05) # set the spacing between axes. 

idx = 0
for neur in neurs:
    firing_field = np.zeros((arena_length, arena_length))*np.nan
    for x in range(arena_length):
        for y in range(arena_length):
            frame_idxs = np.logical_and(reg_xs == x, reg_ys == y)
            fr = np.nanmean(reg_outputs[frame_idxs, neur])
            firing_field[x,y] = fr
    firing_field[np.isnan(firing_field)] = 0    
    if not np.any(firing_field > 0): continue
    ax = plt.subplot(gs1[idx])
    plt.axis('on')
    ax.imshow(firing_field/firing_field.max(), vmin=0, vmax=1)
    ax.set_xticks([])
    ax.set_yticks([])
    
    idx += 1
    if idx == grid_x*grid_y: break
plt.show()
# Out:
# /home/chingf/anaconda3/envs/aronov/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
